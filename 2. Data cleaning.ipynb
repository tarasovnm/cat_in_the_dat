# %%
import numpy as np
import pandas as pd

# %%
train_data = pd.read_csv("data/train.csv", index_col="id")
test_data = pd.read_csv("data/test.csv", index_col="id")
print(f"Shape of train data: {train_data.shape}. Shape of test data: {test_data.shape}")
# Out:
# Shape of train data: (600000, 24). Shape of test data: (400000, 23)

# %% [markdown]
# ### Разделяем признаки по типу

# %%
# Бинарные
bin_features = ['bin_0', 'bin_1', 'bin_2', 'bin_3', 'bin_4']
# Категориальные
nom_features = ['nom_0', 'nom_1', 'nom_2', 'nom_3', 'nom_4']
# Хеш
hex_features = ['nom_5', 'nom_6', 'nom_7', 'nom_8', 'nom_9']
# Порядковые
ord_features = ['ord_0', 'ord_1', 'ord_2', 'ord_3', 'ord_4', 'ord_5']
# Цикличные
cyc_features = ['day', 'month']

# %% [markdown]
# ### Удаляем лишние столбцы

# %% [markdown]
# ### Удаляем выбросы

# %% [markdown]
# ### Заполняем пропущенные значения

# %%
train_data.head()
# Out:
#     bin_0  bin_1  bin_2 bin_3 bin_4 nom_0      nom_1    nom_2       nom_3  \
# id
# 0     0.0    0.0    0.0     F     N   Red  Trapezoid  Hamster      Russia
# 1     1.0    1.0    0.0     F     Y   Red       Star  Axolotl         NaN
# 2     0.0    1.0    0.0     F     N   Red        NaN  Hamster      Canada
# 3     NaN    0.0    0.0     F     N   Red     Circle  Hamster     Finland
# 4     0.0    NaN    0.0     T     N   Red   Triangle  Hamster  Costa Rica
#
#        nom_4  ...      nom_9 ord_0        ord_1     ord_2 ord_3  ord_4 ord_5  \
# id            ...
# 0    Bassoon  ...  02e7c8990   3.0  Contributor       Hot     c      U    Pw
# 1   Theremin  ...  f37df64af   3.0  Grandmaster      Warm     e      X    pE
# 2    Bassoon  ...        NaN   3.0          NaN  Freezing     n      P    eN
# 3   Theremin  ...  f9d456e57   1.0       Novice  Lava Hot     a      C   NaN
# 4        NaN  ...  c5361037c   3.0  Grandmaster      Cold     h      C    OZ
#
#     day month target
# id
# ...

# %% [markdown]
# **Бинарные признаки**

# %%
# # dictionary to map the feature
# bin_dict = {'T':1, 'F':0, 'Y':1, 'N':0}

# # Maping the category values in our dict
# train_data['bin_3'] = train_data['bin_3'].map(bin_dict)
# train_data['bin_4'] = train_data['bin_4'].map(bin_dict)
# test_data['bin_3'] = test_data['bin_3'].map(bin_dict)
# test_data['bin_4'] = test_data['bin_4'].map(bin_dict)

# %%
# train_data[bin_features] = train_data[bin_features].fillna(0)
# test_data[bin_features] = test_data[bin_features].fillna(0)

# %% [markdown]
# **Номинальные признаки**

# %%
# train_data[nom_features] = train_data[nom_features].fillna("NAN")
# test_data[nom_features] = test_data[nom_features].fillna("NAN")

# train_data[hex_features] = train_data[hex_features].fillna("NAN")
# test_data[hex_features] = test_data[hex_features].fillna("NAN")

# %% [markdown]
# **Порядковые признаки**

# %%
# train_data[ord_features]

# %%
train_data[ord_features].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 600000 entries, 0 to 599999
# Data columns (total 6 columns):
# ord_0    581712 non-null float64
# ord_1    581959 non-null object
# ord_2    581925 non-null object
# ord_3    582084 non-null object
# ord_4    582070 non-null object
# ord_5    582287 non-null object
# dtypes: float64(1), object(5)
# memory usage: 32.0+ MB

# %%
# Самое частое значение в столбце
# vc = train_data['ord_2'].value_counts()
# vcc = vc.loc[vc ==vc.sort_values().iloc[-1]].index[0]

# %%
# for col in ord_features:
#     vc = train_data[col].value_counts()
#     most_common_value = vc.loc[vc ==vc.sort_values().iloc[-1]].index[0]
#     train_data[[col]] = train_data[[col]].fillna(most_common_value)
#     test_data[[col]] = test_data[[col]].fillna(most_common_value)

# %% [markdown]
# **Оставшиеся признаки**

# %%
train_data[cyc_features].head()
# Out:
#     day  month
# id
# 0   6.0    3.0
# 1   7.0    7.0
# 2   5.0    9.0
# 3   3.0    3.0
# 4   5.0   12.0

# %%
# for col in cyc_features:
#     vc = train_data[col].value_counts()
#     most_common_value = vc.loc[vc ==vc.sort_values().iloc[-1]].index[0]
#     train_data[[col]] = train_data[[col]].fillna(most_common_value)
#     test_data[[col]] = test_data[[col]].fillna(most_common_value)

# %%
# train_data = train_data.fillna("NAN")
# test_data = test_data.fillna("NAN")

# imp_cat = SimpleImputer(strategy='most_frequent')
# train_data = imp_cat.fit_transform(train_data)
# test_data = imp_cat.fit_transform(test_data)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 600000 entries, 0 to 599999
# Data columns (total 24 columns):
# bin_0     582106 non-null float64
# bin_1     581997 non-null float64
# bin_2     582070 non-null float64
# bin_3     581986 non-null object
# bin_4     581953 non-null object
# nom_0     581748 non-null object
# nom_1     581844 non-null object
# nom_2     581965 non-null object
# nom_3     581879 non-null object
# nom_4     581965 non-null object
# nom_5     582222 non-null object
# nom_6     581869 non-null object
# nom_7     581997 non-null object
# nom_8     582245 non-null object
# nom_9     581927 non-null object
# ord_0     581712 non-null float64
# ord_1     581959 non-null object
# ord_2     581925 non-null object
# ord_3     582084 non-null object
# ord_4     582070 non-null object
# ord_5     582287 non-null object
# day       582048 non-null float64
# month     582012 non-null float64
# target    600000 non-null int64
# ...

# %%
train_data.head()
# Out:
#     bin_0  bin_1  bin_2 bin_3 bin_4 nom_0      nom_1    nom_2       nom_3  \
# id
# 0     0.0    0.0    0.0     F     N   Red  Trapezoid  Hamster      Russia
# 1     1.0    1.0    0.0     F     Y   Red       Star  Axolotl         NaN
# 2     0.0    1.0    0.0     F     N   Red        NaN  Hamster      Canada
# 3     NaN    0.0    0.0     F     N   Red     Circle  Hamster     Finland
# 4     0.0    NaN    0.0     T     N   Red   Triangle  Hamster  Costa Rica
#
#        nom_4  ...      nom_9 ord_0        ord_1     ord_2 ord_3  ord_4 ord_5  \
# id            ...
# 0    Bassoon  ...  02e7c8990   3.0  Contributor       Hot     c      U    Pw
# 1   Theremin  ...  f37df64af   3.0  Grandmaster      Warm     e      X    pE
# 2    Bassoon  ...        NaN   3.0          NaN  Freezing     n      P    eN
# 3   Theremin  ...  f9d456e57   1.0       Novice  Lava Hot     a      C   NaN
# 4        NaN  ...  c5361037c   3.0  Grandmaster      Cold     h      C    OZ
#
#     day month target
# id
# ...

# %% [markdown]
# ### Создаем новые характеристики (Feature engineering)

# %% [markdown]
# ### Сохраняем очищенные данные в файл

# %%
train_data.to_csv('data/cleaned_train_data.csv', header=True)
test_data.to_csv('data/cleaned_test_data.csv', header=True)
